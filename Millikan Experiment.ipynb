# %% [markdown]
# Planks constant by Millikan Experiment

# %%
from numpy import loadtxt
import matplotlib.pyplot as plt
data=loadtxt("millikan.txt",float)

# %%
from numpy import loadtxt
import matplotlib.pyplot as plt
data=loadtxt("millikan.txt",float)  
x=data[:,0]
y=data[:,1]
N=len(x)
Ex=sum(x)/N
Ey=sum(y)/N
Exx=sum(x**2)/N
Exy=sum(x*y)/N
m=(Exy -Ex *Ey)/(Exx -Ex**2)     #slope
c=(Exx*Ey -Ex*Exy)/(Exx -Ex**2)   #intercept
print("slope =",m)
print("intercept= ",c)
print("planks constant= ",m*(1.6e-19))
f=m*x+c
plt.plot(x,y,"ko")
plt.plot(x,f)
plt.savefig("squarefit.png")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# slope = 4.088227358517516e-15
# intercept=  -1.7312358039813558
# planks constant=  6.541163773628025e-34
